# %%
import pandas as pd 
import json 
import requests

# %%
yelp = pd.read_json('json_files/yelp.json')
# yelp = pd.json_normalize(yelp)
yelp.head()
# Out:
#                          Name  Rating  Review Count Price  \
# 0            Afrokanza Lounge     1.0             2  None
# 1  Griyo Caribbean Restaurant     1.0             3  None
# 2                 Burger King     1.5            27     $
# 3                     Wendy's     1.5            29     $
# 4        Tims Four Kings Cafe     2.0             1     $
#
#                                        Address
# 0      1578 Bardstown Rd, Louisville, KY 40205
# 1           519 W Oak St, Louisville, KY 40203
# 2    4030 Shelbyville Rd, Louisville, KY 40207
# 3  978 Breckenridge Lane, Louisville, KY 40207
# 4       4642 Jennings Ln, Louisville, KY 40218

# %%
health = pd.read_csv('json_files/local_working.csv')
health.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Ins_TypeDesc     EstablishmentName  \
# 0          3829        3829     FOLLOWUP     DOLLAR TREE #5046
# 1          3293        3293    COMPLAINT     ADDIS BAR & GRILL
# 2          1547        1547     FOLLOWUP        SPEEDWAY #9712
# 3          3621        3621     FOLLOWUP     MIAMI FOOD MARKET
# 4          1526        1526     FOLLOWUP  FAMILY DOLLAR #20750
#
#                 Address        City State    Zip InspectionDate  score  Grade  \
# 0       10309 DIXIE HWY  LOUISVILLE    KY  40272     2023-07-26      0    NaN
# 1          109 S 4TH ST  LOUISVILLE    KY  40202     2023-08-14      0    NaN
# 2  4547 TAYLORSVILLE RD  LOUISVILLE    KY  40220     2023-04-27      0    NaN
# 3         5307 S 3RD ST  LOUISVILLE    KY  40214     2023-08-14      0    NaN
# 4     3022 PORTLAND AVE  LOUISVILLE    KY  40212     2022-11-22      0    NaN
#
#    ObjectId
# 0      3830
# 1      3294
# 2      1548
# 3      3622
# 4      1527

# %%
yelp.shape
# Out:
# (971, 5)

# %%
health.shape
# Out:
# (10, 12)

# %%
yelp['Address'] = yelp['Address'].str.split(',').str[0]
yelp['Rating'] = (yelp['Rating']*20).astype(int)
yelp.head()
# Out:
#                          Name  Rating  Review Count Price  \
# 0            Afrokanza Lounge      20             2  None
# 1  Griyo Caribbean Restaurant      20             3  None
# 2                 Burger King      30            27     $
# 3                     Wendy's      30            29     $
# 4        Tims Four Kings Cafe      40             1     $
#
#                  Address
# 0      1578 Bardstown Rd
# 1           519 W Oak St
# 2    4030 Shelbyville Rd
# 3  978 Breckenridge Lane
# 4       4642 Jennings Ln

# %%
health['Address'] = health['Address'].str.lower().str.strip()
yelp['Address'] = yelp['Address'].str.lower().str.strip()

# %%
merged_df = health.merge(yelp, on='Address', how='left')
merged_df = merged_df.sort_values('Rating', ascending=True)
merged_df = merged_df[['EstablishmentName', 'Address', 'score', 'Rating', 'Review Count']]
merged_df.head(20)
# Out:
#               EstablishmentName                   Address  score  Rating  \
# 1             ADDIS BAR & GRILL              109 s 4th st      0    80.0
# 7                 GOT MUNCHIES?  1812 w muhammad ali blvd      0    80.0
# 9          FAMILY DOLLAR #22117             5312 s 3rd st      0    90.0
# 10         FAMILY DOLLAR #22117             5312 s 3rd st      0    90.0
# 0             DOLLAR TREE #5046           10309 dixie hwy      0     NaN
# 2                SPEEDWAY #9712      4547 taylorsville rd      0     NaN
# 3             MIAMI FOOD MARKET             5307 s 3rd st      0     NaN
# 4          FAMILY DOLLAR #20750         3022 portland ave      0     NaN
# 5                      ME SALSA                       NaN      0     NaN
# 6    LITTLE STORE FOOD AND MORE       2600 hale ave ste 2      0     NaN
# 8   STOMPING GROUNDS COFFEE CO.           10019 dixie hwy      0     NaN
#
#     Review Count
# 1          124.0
# 7           43.0
# 9            3.0
# 10          40.0
# 0            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 8            NaN
