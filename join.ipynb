# %%
import pandas as pd 
import json 
import requests

# %%
yelp = pd.read_json('json_files/yelp.json')
# yelp = pd.json_normalize(yelp)
yelp.head()
# Out:
#    Unnamed: 0                        Name  Rating  Review Count Price  \
# 0         301            Afrokanza Lounge     1.0             1  None
# 1         460  Griyo Caribbean Restaurant     1.0             3  None
# 2         682              Steak ’n Shake     1.5           101     $
# 3         881                  McDonald's     1.5            78     $
# 4         696                 Dairy Queen     1.5            48     $
#
#                                       Address
# 0     1578 Bardstown Rd, Louisville, KY 40205
# 1          519 W Oak St, Louisville, KY 40203
# 2         4545 Outer Lp, Louisville, KY 40219
# 3     1245 Bardstown Rd, Louisville, KY 40204
# 4  3221 Poplar Level Rd, Louisville, KY 40213

# %%
health = pd.read_csv('local_working.csv')
health.head()
# Out:
#    EstablishmentID  InspectionID Ins_TypeDesc     EstablishmentName  \
# 0            98505       1749114      REGULAR   MI SUENO RESTAURANT
# 1           118055       1748425      REGULAR         DAISUKI SUSHI
# 2            99781       1725518      REGULAR           HAPPY CHINA
# 3           115438       1725737     FOLLOWUP  EXPRESSWAY FOOD MART
# 4           107689       1704587      REGULAR          BEST WESTERN
#
#    PlaceName               Address  Address2        City State    Zip  \
# 0        NaN     3425 BARDSTOWN RD       NaN  LOUISVILLE    KY  40218
# 1        NaN     1604 BARDSTOWN RD       NaN  LOUISVILLE    KY  40205
# 2        NaN  9128 TAYLORSVILLE RD       NaN  LOUISVILLE    KY  40299
# 3        NaN       1420 W BROADWAY       NaN  LOUISVILLE    KY  40203
# 4        NaN        4110 DIXIE HWY       NaN  LOUISVILLE    KY  40216
#
#                      TypeDescription InspectionDate  score Grade  \
# 0                       FOOD SERVICE     2023-04-18     70     C
# 1                       FOOD SERVICE     2023-04-14     71     C
# 2                       FOOD SERVICE     2022-12-22     72     C
# 3  RETAIL-FOOD  10,000 SQ FT OR LESS     2022-12-27     73     C
# 4                       FOOD SERVICE     2022-09-28     74     C
#
#              NameSearch  Intersection  ObjectId
# 0   MI SUENO RESTAURANT           NaN      4803
# 1         DAISUKI SUSHI           NaN     10803
# 2           HAPPY CHINA           NaN      5049
# 3  EXPRESSWAY FOOD MART           NaN      9916
# 4          BEST WESTERN           NaN      6908

# %%
yelp.shape
# Out:
# (968, 6)

# %%
health.shape
# Out:
# (10169, 17)

# %%
yelp['Address'] = yelp['Address'].str.split(',').str[0]
yelp['Rating'] = (yelp['Rating']*20).astype(int)
yelp.head()
# Out:
#    Unnamed: 0                        Name  Rating  Review Count Price  \
# 0         301            Afrokanza Lounge      20             1  None
# 1         460  Griyo Caribbean Restaurant      20             3  None
# 2         682              Steak ’n Shake      30           101     $
# 3         881                  McDonald's      30            78     $
# 4         696                 Dairy Queen      30            48     $
#
#                 Address
# 0     1578 Bardstown Rd
# 1          519 W Oak St
# 2         4545 Outer Lp
# 3     1245 Bardstown Rd
# 4  3221 Poplar Level Rd

# %%
health['Address'] = health['Address'].str.lower().str.strip()
yelp['Address'] = yelp['Address'].str.lower().str.strip()

# %%
merged_df = health.merge(yelp, on='Address', how='left')
merged_df = merged_df.sort_values('Rating', ascending=True)
merged_df = merged_df[['EstablishmentName', 'Address', 'score', 'Rating', 'Review Count']]
merged_df.head(20)
# Out:
#                        EstablishmentName             Address  score  Rating  \
# 273           GRIYO CARIBBEAN RESTAURANT        519 w oak st     91    20.0
# 2019                    AFROKANZA LOUNGE   1578 bardstown rd     96    20.0
# 855           GRIYO CARIBBEAN RESTAURANT        519 w oak st     94    20.0
# 618           GRIYO CARIBBEAN RESTAURANT        519 w oak st     93    20.0
# 2168          GRIYO CARIBBEAN RESTAURANT        519 w oak st     96    20.0
# 275           GRIYO CARIBBEAN RESTAURANT        519 w oak st     91    20.0
# 761                     AFROKANZA LOUNGE   1578 bardstown rd     94    20.0
# 1019      U OF L CATERING SERVICES (SAC)     2100 s floyd st     95    30.0
# 5459                       WENDY'S (SAC)     2100 s floyd st     99    30.0
# 4704                          MCDONALD'S   1245 bardstown rd     98    30.0
# 8661                      LUEBERRY (SRC)     2100 s floyd st    100    30.0
# 8684                      LUEBERRY (SRC)     2100 s floyd st    100    30.0
# 8697                  EIFFEL PIZZA (SAC)     2100 s floyd st    100    30.0
# 4695                          MCDONALD'S   1245 bardstown rd     98    30.0
# 1979                    BURGER KING #889  2700 crittenden dr     96    30.0
# 9701  EINSTEIN BROTHERS BAGELS (BINGHAM)     2100 s floyd st    100    30.0
# 9968              POD ACADEMIC (BELKNAP)     2100 s floyd st    100    30.0
# 4242                  STARBUCKS ESKSTROM     2100 s floyd st     98    30.0
# 4091                       WENDY'S (SAC)     2100 s floyd st     98    30.0
# 9009                          MCDONALD'S   1245 bardstown rd    100    30.0
#
#       Review Count
# 273            3.0
# 2019           1.0
# 855            3.0
# 618            3.0
# 2168           3.0
# 275            3.0
# 761            1.0
# 1019           5.0
# 5459           5.0
# 4704          78.0
# 8661           5.0
# 8684           5.0
# 8697           5.0
# 4695          78.0
# 1979          23.0
# 9701           5.0
# 9968           5.0
# 4242           5.0
# 4091           5.0
# 9009          78.0
