# %%
import pandas as pd
import requests
import json
import urllib3
from pandas import json_normalize

# %%
# url = 'https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
url = 'https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
r = requests.get(url)
json = r.json()
# json



# ('https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')
# df.head()

# %%
json.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'fields', 'exceededTransferLimit', 'features'])

# %%
df = pd.json_normalize(json, record_path =['features'])
df
# df.to_csv("rest_data.csv")
# Out:
#      attributes.EstablishmentID  attributes.InspectionID  \
# 0                         29956                  1684470
# 1                         29967                  1699737
# 2                         29979                  1698679
# 3                         29979                  1698680
# 4                         29979                  1731827
# ..                          ...                      ...
# 995                       37954                  1708646
# 996                       37954                  1707312
# 997                       37954                  1713124
# 998                       37956                  1706558
# 999                       37956                  1719254
#
#     attributes.Ins_TypeDesc attributes.EstablishmentName attributes.PlaceName  \
# 0                   REGULAR                    CVS #6211                 None
# 1                   REGULAR       NEIGHBORHOOD FOOD MART                 None
# 2                   REGULAR            CIRCLE K #4700075                 None
# 3                   REGULAR            CIRCLE K #4700075                 None
# 4                   REGULAR            CIRCLE K #4700075                 None
# ..                      ...                          ...                  ...
# 995                  SURVEY     KENTUCKIANA SPECIALTY #4                 None
# 996                  SURVEY     KENTUCKIANA SPECIALTY #4                 None
# 997                  SURVEY     KENTUCKIANA SPECIALTY #4                 None
# 998                 REGULAR     KENTUCKIANA SPECIALTY #6                 None
# 999                 REGULAR     KENTUCKIANA SPECIALTY #6                 None
#
#     attributes.Address attributes.Address2 attributes.City attributes.State  \
# 0    3721 LEXINGTON RD                None      LOUISVILLE               KY
# 1       542 LAMPTON ST                None      LOUISVILLE               KY
# 2       1630 ARTHUR ST                None      LOUISVILLE               KY
# 3       1630 ARTHUR ST                None      LOUISVILLE               KY
# 4       1630 ARTHUR ST                None      LOUISVILLE               KY
# ..                 ...                 ...             ...              ...
# 995               None                None      LOUISVILLE               KY
# 996               None                None      LOUISVILLE               KY
# 997               None                None      LOUISVILLE               KY
# 998               None                None      LOUISVILLE               KY
# 999               None                None      LOUISVILLE               KY
#
#      attributes.Zip         attributes.TypeDescription  \
# 0             40207                PRE-PACKAGED RETAIL
# 1             40203        SUPERMARKET WITH PROCESSING
# 2             40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# 3             40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# 4             40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# ..              ...                                ...
# 995           40202   SELF-CONTAINED MOBILE FOOD UNITS
# 996           40202   SELF-CONTAINED MOBILE FOOD UNITS
# 997           40202   SELF-CONTAINED MOBILE FOOD UNITS
# 998           40202   SELF-CONTAINED MOBILE FOOD UNITS
# 999           40202   SELF-CONTAINED MOBILE FOOD UNITS
#
#     attributes.InspectionDate  attributes.score attributes.Grade  \
# 0         2022-07-06 00:00:00               100             None
# 1         2022-09-07 00:00:00                97             None
# 2         2022-09-01 00:00:00                97                A
# 3         2022-09-01 00:00:00                98             None
# 4         2023-01-27 00:00:00                95                A
# ..                        ...               ...              ...
# 995       2022-08-22 00:00:00                98             None
# 996       2022-08-24 00:00:00               100             None
# 997       2022-08-20 00:00:00                98             None
# 998       2022-09-16 00:00:00                98                A
# 999       2022-11-25 00:00:00                96                A
#
#         attributes.NameSearch attributes.Intersection  attributes.ObjectId
# 0                   CVS #6211                    None                    1
# 1      NEIGHBORHOOD FOOD MART                    None                    2
# 2           CIRCLE K #4700075                    None                    3
# 3           CIRCLE K #4700075                    None                    4
# 4           CIRCLE K #4700075                    None                    5
# ..                        ...                     ...                  ...
# 995  KENTUCKIANA SPECIALTY #4                    None                  996
# 996  KENTUCKIANA SPECIALTY #4                    None                  997
# 997  KENTUCKIANA SPECIALTY #4                    None                  998
# 998  KENTUCKIANA SPECIALTY #6                    None                  999
# 999  KENTUCKIANA SPECIALTY #6                    None                 1000
#
# [1000 rows x 17 columns]

# %%
# type(json['properties'])
# df = pd.DataFrame(json['features'])
# df.to_csv("rest_data.csv")

# %%
# df = pd.read_csv('rest_data.csv')
print(sorted(df))
# Out:
# ['attributes.Address', 'attributes.Address2', 'attributes.City', 'attributes.EstablishmentID', 'attributes.EstablishmentName', 'attributes.Grade', 'attributes.Ins_TypeDesc', 'attributes.InspectionDate', 'attributes.InspectionID', 'attributes.Intersection', 'attributes.NameSearch', 'attributes.ObjectId', 'attributes.PlaceName', 'attributes.State', 'attributes.TypeDescription', 'attributes.Zip', 'attributes.score']
