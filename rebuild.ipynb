# %%
import pandas as pd
import requests
import json
import urllib3
from pandas import json_normalize

# %%
# url = 'https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson'
url = 'https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json'
r = requests.get(url)
json = r.json()
json



# ('https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/FoodServiceData/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')
# df.head()
# Out:
# {'objectIdFieldName': 'ObjectId',
#  'uniqueIdField': {'name': 'ObjectId', 'isSystemMaintained': True},
#  'globalIdFieldName': '',
#  'fields': [{'name': 'EstablishmentID',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'EstablishmentID',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'InspectionID',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'InspectionID',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Ins_TypeDesc',
#    'type': 'esriFieldTypeString',
#    'alias': 'Ins_TypeDesc',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'EstablishmentName',
#    'type': 'esriFieldTypeString',
#    'alias': 'EstablishmentName',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'PlaceName',
#    'type': 'esriFieldTypeString',
#    'alias': 'PlaceName',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Address',
#    'type': 'esriFieldTypeString',
#    'alias': 'Address',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Address2',
#    'type': 'esriFieldTypeString',
#    'alias': 'Address2',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'City',
#    'type': 'esriFieldTypeString',
#    'alias': 'City',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'State',
#    'type': 'esriFieldTypeString',
#    'alias': 'State',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Zip',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'Zip',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'TypeDescription',
#    'type': 'esriFieldTypeString',
#    'alias': 'TypeDescription',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'InspectionDate',
#    'type': 'esriFieldTypeString',
#    'alias': 'InspectionDate',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 256,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'score',
#    'type': 'esriFieldTypeInteger',
#    'alias': 'score',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Grade',
#    'type': 'esriFieldTypeString',
#    'alias': 'Grade',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'NameSearch',
#    'type': 'esriFieldTypeString',
#    'alias': 'NameSearch',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'Intersection',
#    'type': 'esriFieldTypeString',
#    'alias': 'Intersection',
#    'sqlType': 'sqlTypeNVarchar',
#    'length': 4000,
#    'domain': None,
#    'defaultValue': None},
#   {'name': 'ObjectId',
#    'type': 'esriFieldTypeOID',
#    'alias': 'ObjectId',
#    'sqlType': 'sqlTypeInteger',
#    'domain': None,
#    'defaultValue': None}],
#  'exceededTransferLimit': True,
#  'features': [{'attributes': {'EstablishmentID': 29956,
#     'InspectionID': 1684470,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CVS #6211',
#     'PlaceName': None,
#     'Address': '3721 LEXINGTON RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2022-07-06 00:00:00',
#     'score': 100,
#     'Grade': None,
#     'NameSearch': 'CVS #6211',
#     'Intersection': None,
#     'ObjectId': 1}},
#   {'attributes': {'EstablishmentID': 29967,
#     'InspectionID': 1699737,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'NEIGHBORHOOD FOOD MART',
#     'PlaceName': None,
#     'Address': '542 LAMPTON ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40203,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2022-09-07 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'NEIGHBORHOOD FOOD MART',
#     'Intersection': None,
#     'ObjectId': 2}},
#   {'attributes': {'EstablishmentID': 29979,
#     'InspectionID': 1698679,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CIRCLE K #4700075',
#     'PlaceName': None,
#     'Address': '1630 ARTHUR ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40208,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-09-01 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'CIRCLE K #4700075',
#     'Intersection': None,
#     'ObjectId': 3}},
#   {'attributes': {'EstablishmentID': 29979,
#     'InspectionID': 1698680,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CIRCLE K #4700075',
#     'PlaceName': None,
#     'Address': '1630 ARTHUR ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40208,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-09-01 00:00:00',
#     'score': 98,
#     'Grade': None,
#     'NameSearch': 'CIRCLE K #4700075',
#     'Intersection': None,
#     'ObjectId': 4}},
#   {'attributes': {'EstablishmentID': 29979,
#     'InspectionID': 1731827,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CIRCLE K #4700075',
#     'PlaceName': None,
#     'Address': '1630 ARTHUR ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40208,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-01-27 00:00:00',
#     'score': 95,
#     'Grade': 'A',
#     'NameSearch': 'CIRCLE K #4700075',
#     'Intersection': None,
#     'ObjectId': 5}},
#   {'attributes': {'EstablishmentID': 29979,
#     'InspectionID': 1731828,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CIRCLE K #4700075',
#     'PlaceName': None,
#     'Address': '1630 ARTHUR ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40208,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-01-27 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'CIRCLE K #4700075',
#     'Intersection': None,
#     'ObjectId': 6}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1700824,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-09-12 00:00:00',
#     'score': 98,
#     'Grade': None,
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 7}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1678623,
#     'Ins_TypeDesc': 'SURVEY',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-05-26 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 8}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1698630,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-09-01 00:00:00',
#     'score': 94,
#     'Grade': 'A',
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 9}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1698631,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-09-01 00:00:00',
#     'score': 95,
#     'Grade': None,
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 10}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1735940,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-02-17 00:00:00',
#     'score': 94,
#     'Grade': 'A',
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 11}},
#   {'attributes': {'EstablishmentID': 30043,
#     'InspectionID': 1735941,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'F&Y SUPERMARKET',
#     'PlaceName': None,
#     'Address': '3801 W MARKET ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-02-17 00:00:00',
#     'score': 91,
#     'Grade': None,
#     'NameSearch': 'F&Y SUPERMARKET',
#     'Intersection': None,
#     'ObjectId': 12}},
#   {'attributes': {'EstablishmentID': 30075,
#     'InspectionID': 1673914,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CVS #6199',
#     'PlaceName': None,
#     'Address': '3130 PORTLAND AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2022-05-23 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'CVS #6199',
#     'Intersection': None,
#     'ObjectId': 13}},
#   {'attributes': {'EstablishmentID': 30075,
#     'InspectionID': 1678618,
#     'Ins_TypeDesc': 'SURVEY',
#     'EstablishmentName': 'CVS #6199',
#     'PlaceName': None,
#     'Address': '3130 PORTLAND AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2022-05-27 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'CVS #6199',
#     'Intersection': None,
#     'ObjectId': 14}},
#   {'attributes': {'EstablishmentID': 30085,
#     'InspectionID': 1665230,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'SPEEDWAY #9709',
#     'PlaceName': None,
#     'Address': '4239 POPLAR LEVEL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-04-08 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #9709',
#     'Intersection': None,
#     'ObjectId': 15}},
#   {'attributes': {'EstablishmentID': 30085,
#     'InspectionID': 1705774,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9709',
#     'PlaceName': None,
#     'Address': '4239 POPLAR LEVEL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-10-03 00:00:00',
#     'score': 96,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #9709',
#     'Intersection': None,
#     'ObjectId': 16}},
#   {'attributes': {'EstablishmentID': 30085,
#     'InspectionID': 1705775,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9709',
#     'PlaceName': None,
#     'Address': '4239 POPLAR LEVEL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-10-03 00:00:00',
#     'score': 95,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #9709',
#     'Intersection': None,
#     'ObjectId': 17}},
#   {'attributes': {'EstablishmentID': 30085,
#     'InspectionID': 1744034,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9709',
#     'PlaceName': None,
#     'Address': '4239 POPLAR LEVEL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-03-24 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #9709',
#     'Intersection': None,
#     'ObjectId': 18}},
#   {'attributes': {'EstablishmentID': 30085,
#     'InspectionID': 1744035,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9709',
#     'PlaceName': None,
#     'Address': '4239 POPLAR LEVEL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-03-24 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #9709',
#     'Intersection': None,
#     'ObjectId': 19}},
#   {'attributes': {'EstablishmentID': 30108,
#     'InspectionID': 1684741,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9515',
#     'PlaceName': None,
#     'Address': '2720 TAYLORSVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40205,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-07-06 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #9515',
#     'Intersection': None,
#     'ObjectId': 20}},
#   {'attributes': {'EstablishmentID': 30108,
#     'InspectionID': 1684742,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9515',
#     'PlaceName': None,
#     'Address': '2720 TAYLORSVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40205,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-07-06 00:00:00',
#     'score': 100,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #9515',
#     'Intersection': None,
#     'ObjectId': 21}},
#   {'attributes': {'EstablishmentID': 30108,
#     'InspectionID': 1724197,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9515',
#     'PlaceName': None,
#     'Address': '2720 TAYLORSVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40205,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-12-16 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #9515',
#     'Intersection': None,
#     'ObjectId': 22}},
#   {'attributes': {'EstablishmentID': 30108,
#     'InspectionID': 1724198,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #9515',
#     'PlaceName': None,
#     'Address': '2720 TAYLORSVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40205,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-12-16 00:00:00',
#     'score': 100,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #9515',
#     'Intersection': None,
#     'ObjectId': 23}},
#   {'attributes': {'EstablishmentID': 30154,
#     'InspectionID': 1737641,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'CIRCLE K #4700117',
#     'PlaceName': None,
#     'Address': '9619 WHIPPS MILL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40222,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2023-02-24 00:00:00',
#     'score': 98,
#     'Grade': None,
#     'NameSearch': 'CIRCLE K #4700117',
#     'Intersection': None,
#     'ObjectId': 24}},
#   {'attributes': {'EstablishmentID': 30248,
#     'InspectionID': 1697515,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'NEWCOMER ACADEMY',
#     'PlaceName': None,
#     'Address': '3741 PULLIAM DR',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40218,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-08-29 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'NEWCOMER ACADEMY',
#     'Intersection': None,
#     'ObjectId': 25}},
#   {'attributes': {'EstablishmentID': 30248,
#     'InspectionID': 1740736,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'NEWCOMER ACADEMY',
#     'PlaceName': None,
#     'Address': '3741 PULLIAM DR',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40218,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-10 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'NEWCOMER ACADEMY',
#     'Intersection': None,
#     'ObjectId': 26}},
#   {'attributes': {'EstablishmentID': 30264,
#     'InspectionID': 1692958,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #5043',
#     'PlaceName': None,
#     'Address': '4417 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40216,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-08-09 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #5043',
#     'Intersection': None,
#     'ObjectId': 27}},
#   {'attributes': {'EstablishmentID': 30264,
#     'InspectionID': 1692959,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #5043',
#     'PlaceName': None,
#     'Address': '4417 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40216,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-08-09 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #5043',
#     'Intersection': None,
#     'ObjectId': 28}},
#   {'attributes': {'EstablishmentID': 30264,
#     'InspectionID': 1732669,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #5043',
#     'PlaceName': None,
#     'Address': '4417 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40216,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-02-01 00:00:00',
#     'score': 94,
#     'Grade': 'A',
#     'NameSearch': 'SPEEDWAY #5043',
#     'Intersection': None,
#     'ObjectId': 29}},
#   {'attributes': {'EstablishmentID': 30264,
#     'InspectionID': 1732670,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SPEEDWAY #5043',
#     'PlaceName': None,
#     'Address': '4417 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40216,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2023-02-01 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'SPEEDWAY #5043',
#     'Intersection': None,
#     'ObjectId': 30}},
#   {'attributes': {'EstablishmentID': 30337,
#     'InspectionID': 1664450,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PIC PAC',
#     'PlaceName': None,
#     'Address': '3110 TAYLOR BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40215,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2022-04-11 00:00:00',
#     'score': 92,
#     'Grade': None,
#     'NameSearch': 'PIC PAC',
#     'Intersection': None,
#     'ObjectId': 31}},
#   {'attributes': {'EstablishmentID': 30337,
#     'InspectionID': 1736243,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PIC PAC',
#     'PlaceName': None,
#     'Address': '3110 TAYLOR BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40215,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2023-02-20 00:00:00',
#     'score': 91,
#     'Grade': None,
#     'NameSearch': 'PIC PAC',
#     'Intersection': None,
#     'ObjectId': 32}},
#   {'attributes': {'EstablishmentID': 30337,
#     'InspectionID': 1740411,
#     'Ins_TypeDesc': 'COMPLAINT',
#     'EstablishmentName': 'PIC PAC',
#     'PlaceName': None,
#     'Address': '3110 TAYLOR BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40215,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2023-02-20 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'PIC PAC',
#     'Intersection': None,
#     'ObjectId': 33}},
#   {'attributes': {'EstablishmentID': 30337,
#     'InspectionID': 1740412,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'PIC PAC',
#     'PlaceName': None,
#     'Address': '3110 TAYLOR BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40215,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2023-02-21 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'PIC PAC',
#     'Intersection': None,
#     'ObjectId': 34}},
#   {'attributes': {'EstablishmentID': 30374,
#     'InspectionID': 1673635,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SUGAR AND SPICE',
#     'PlaceName': None,
#     'Address': '5613 BARDSTOWN RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2022-05-18 00:00:00',
#     'score': 99,
#     'Grade': None,
#     'NameSearch': 'SUGAR AND SPICE',
#     'Intersection': None,
#     'ObjectId': 35}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1686030,
#     'Ins_TypeDesc': 'COMPLAINT',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-06-28 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 36}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1682788,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-06-28 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 37}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1682789,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-06-28 00:00:00',
#     'score': 94,
#     'Grade': None,
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 38}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1684121,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-07-05 00:00:00',
#     'score': 100,
#     'Grade': None,
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 39}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1724804,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-12-19 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 40}},
#   {'attributes': {'EstablishmentID': 30394,
#     'InspectionID': 1724805,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': "SAM'S CLUB #8276",
#     'PlaceName': None,
#     'Address': '6622 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'RETAIL-FOOD  10,000 SQ FT OR LESS',
#     'InspectionDate': '2022-12-19 00:00:00',
#     'score': 99,
#     'Grade': None,
#     'NameSearch': "SAM'S CLUB #8276",
#     'Intersection': None,
#     'ObjectId': 41}},
#   {'attributes': {'EstablishmentID': 30411,
#     'InspectionID': 1721988,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'WALGREENS #12322',
#     'PlaceName': None,
#     'Address': '808 EASTERN PKWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'PRE-PACKAGED RETAIL',
#     'InspectionDate': '2022-12-07 00:00:00',
#     'score': 95,
#     'Grade': None,
#     'NameSearch': 'WALGREENS #12322',
#     'Intersection': None,
#     'ObjectId': 42}},
#   {'attributes': {'EstablishmentID': 30425,
#     'InspectionID': 1685452,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'BIG LOTS #226',
#     'PlaceName': None,
#     'Address': '4121 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'SUPERMARKET WITH PROCESSING',
#     'InspectionDate': '2022-07-11 00:00:00',
#     'score': 100,
#     'Grade': None,
#     'NameSearch': 'BIG LOTS #226',
#     'Intersection': None,
#     'ObjectId': 43}},
#   {'attributes': {'EstablishmentID': 30826,
#     'InspectionID': 1715420,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': "TIMOTHY'S ANGELS",
#     'PlaceName': None,
#     'Address': '1351 CATALPA ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2022-11-08 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': "TIMOTHY'S ANGELS",
#     'Intersection': None,
#     'ObjectId': 44}},
#   {'attributes': {'EstablishmentID': 30917,
#     'InspectionID': 1677229,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'PlaceName': None,
#     'Address': '10320 TIMBERWOOD CIRCLE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40223,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2022-06-06 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'Intersection': None,
#     'ObjectId': 45}},
#   {'attributes': {'EstablishmentID': 30917,
#     'InspectionID': 1744461,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'PlaceName': None,
#     'Address': '10320 TIMBERWOOD CIRCLE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40223,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2023-03-27 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'Intersection': None,
#     'ObjectId': 46}},
#   {'attributes': {'EstablishmentID': 30917,
#     'InspectionID': 1715303,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'PlaceName': None,
#     'Address': '10320 TIMBERWOOD CIRCLE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40223,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2022-11-07 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'BRIGHT HORIZONS @ PLAINVIEW SCHOOL',
#     'Intersection': None,
#     'ObjectId': 47}},
#   {'attributes': {'EstablishmentID': 30972,
#     'InspectionID': 1701548,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'KINDER CARE LEARNING CTR #420',
#     'PlaceName': None,
#     'Address': '730 ZORN AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40206,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2022-09-14 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'KINDER CARE LEARNING CTR #420',
#     'Intersection': None,
#     'ObjectId': 48}},
#   {'attributes': {'EstablishmentID': 30972,
#     'InspectionID': 1740536,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'KINDER CARE LEARNING CTR #420',
#     'PlaceName': None,
#     'Address': '730 ZORN AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40206,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2023-03-09 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'KINDER CARE LEARNING CTR #420',
#     'Intersection': None,
#     'ObjectId': 49}},
#   {'attributes': {'EstablishmentID': 30989,
#     'InspectionID': 1699656,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SOUTHSIDE CHRISTIAN',
#     'PlaceName': None,
#     'Address': '5804 SOUTHSIDE DR',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40214,
#     'TypeDescription': 'FOOD SERVICE (DAY CARE / CHILD CARE CENTER',
#     'InspectionDate': '2022-09-07 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'SOUTHSIDE CHRISTIAN',
#     'Intersection': None,
#     'ObjectId': 50}},
#   {'attributes': {'EstablishmentID': 31460,
#     'InspectionID': 1709976,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'ST. NICHOLAS ACADEMY',
#     'PlaceName': None,
#     'Address': '5501 NEW CUT RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40214,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-10-18 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'ST. NICHOLAS ACADEMY',
#     'Intersection': None,
#     'ObjectId': 51}},
#   {'attributes': {'EstablishmentID': 31462,
#     'InspectionID': 1704589,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'MAUPIN ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '1312 CATALPA ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-28 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'MAUPIN ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 52}},
#   {'attributes': {'EstablishmentID': 31462,
#     'InspectionID': 1740129,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'MAUPIN ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '1312 CATALPA ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-08 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'MAUPIN ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 53}},
#   {'attributes': {'EstablishmentID': 31464,
#     'InspectionID': 1704588,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'JOHNSON TRADITIONAL MIDDLE SCHOOL',
#     'PlaceName': None,
#     'Address': '2509 WILSON AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40210,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-28 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'JOHNSON TRADITIONAL MIDDLE SCHOOL',
#     'Intersection': None,
#     'ObjectId': 54}},
#   {'attributes': {'EstablishmentID': 31464,
#     'InspectionID': 1740130,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'JOHNSON TRADITIONAL MIDDLE SCHOOL',
#     'PlaceName': None,
#     'Address': '2509 WILSON AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40210,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-08 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'JOHNSON TRADITIONAL MIDDLE SCHOOL',
#     'Intersection': None,
#     'ObjectId': 55}},
#   {'attributes': {'EstablishmentID': 31466,
#     'InspectionID': 1698664,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PLEASURE RIDGE PARK MAGNET SCHOOL',
#     'PlaceName': None,
#     'Address': '5901 GREENWOOD RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40258,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-01 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'PLEASURE RIDGE PARK MAGNET SCHOOL',
#     'Intersection': None,
#     'ObjectId': 56}},
#   {'attributes': {'EstablishmentID': 31466,
#     'InspectionID': 1740059,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PLEASURE RIDGE PARK MAGNET SCHOOL',
#     'PlaceName': None,
#     'Address': '5901 GREENWOOD RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40258,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-08 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'PLEASURE RIDGE PARK MAGNET SCHOOL',
#     'Intersection': None,
#     'ObjectId': 57}},
#   {'attributes': {'EstablishmentID': 31474,
#     'InspectionID': 1707207,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PORTLAND ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '3410 NORTHWESTERN PKWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-10-07 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'PORTLAND ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 58}},
#   {'attributes': {'EstablishmentID': 31474,
#     'InspectionID': 1738079,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PORTLAND ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '3410 NORTHWESTERN PKWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40212,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-02-27 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'PORTLAND ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 59}},
#   {'attributes': {'EstablishmentID': 31475,
#     'InspectionID': 1706388,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PRICE ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '5001 GARDEN GREEN WAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40218,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-10-05 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'PRICE ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 60}},
#   {'attributes': {'EstablishmentID': 31475,
#     'InspectionID': 1744715,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'PRICE ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '5001 GARDEN GREEN WAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40218,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-28 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'PRICE ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 61}},
#   {'attributes': {'EstablishmentID': 31477,
#     'InspectionID': 1701442,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RANGELAND ELEMENTARY',
#     'PlaceName': None,
#     'Address': '1701 RANGELAND RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-14 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'RANGELAND ELEMENTARY',
#     'Intersection': None,
#     'ObjectId': 62}},
#   {'attributes': {'EstablishmentID': 31477,
#     'InspectionID': 1743732,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RANGELAND ELEMENTARY',
#     'PlaceName': None,
#     'Address': '1701 RANGELAND RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40219,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-22 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'RANGELAND ELEMENTARY',
#     'Intersection': None,
#     'ObjectId': 63}},
#   {'attributes': {'EstablishmentID': 31480,
#     'InspectionID': 1700064,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RUTHERFORD ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '301 SOUTHLAND BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40214,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-08 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'RUTHERFORD ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 64}},
#   {'attributes': {'EstablishmentID': 31480,
#     'InspectionID': 1731861,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RUTHERFORD ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '301 SOUTHLAND BLVD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40214,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-01-27 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'RUTHERFORD ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 65}},
#   {'attributes': {'EstablishmentID': 31482,
#     'InspectionID': 1666625,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EASTERN HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '12400 OLD SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-04-20 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EASTERN HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 66}},
#   {'attributes': {'EstablishmentID': 31482,
#     'InspectionID': 1708185,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EASTERN HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '12400 OLD SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-10-11 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EASTERN HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 67}},
#   {'attributes': {'EstablishmentID': 31482,
#     'InspectionID': 1741431,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EASTERN HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '12400 OLD SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-14 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EASTERN HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 68}},
#   {'attributes': {'EstablishmentID': 31492,
#     'InspectionID': 1699064,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EISENHOWER ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '5300 JESSAMINE DR',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40258,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-02 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EISENHOWER ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 69}},
#   {'attributes': {'EstablishmentID': 31492,
#     'InspectionID': 1738136,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EISENHOWER ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '5300 JESSAMINE DR',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40258,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-02-27 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EISENHOWER ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 70}},
#   {'attributes': {'EstablishmentID': 31496,
#     'InspectionID': 1694030,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'ENGELHARD ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '1004 S 1ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40203,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-08-12 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'ENGELHARD ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 71}},
#   {'attributes': {'EstablishmentID': 31496,
#     'InspectionID': 1728234,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'ENGELHARD ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '1004 S 1ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40203,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-01-11 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'ENGELHARD ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 72}},
#   {'attributes': {'EstablishmentID': 31500,
#     'InspectionID': 1697655,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FAIRDALE ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '10104 MITCHELL HILL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40118,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-08-29 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'FAIRDALE ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 73}},
#   {'attributes': {'EstablishmentID': 31500,
#     'InspectionID': 1739046,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FAIRDALE ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '10104 MITCHELL HILL RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40118,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-01 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'FAIRDALE ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 74}},
#   {'attributes': {'EstablishmentID': 31502,
#     'InspectionID': 1716645,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FAIRDALE HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '1001 FAIRDALE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40118,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-11-14 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'FAIRDALE HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 75}},
#   {'attributes': {'EstablishmentID': 31509,
#     'InspectionID': 1702490,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FERN CREEK ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '8815 FERNDALE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-09-19 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FERN CREEK ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 76}},
#   {'attributes': {'EstablishmentID': 31509,
#     'InspectionID': 1738474,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FERN CREEK ELEMENTARY SCHOOL',
#     'PlaceName': None,
#     'Address': '8815 FERNDALE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-02-27 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FERN CREEK ELEMENTARY SCHOOL',
#     'Intersection': None,
#     'ObjectId': 77}},
#   {'attributes': {'EstablishmentID': 31511,
#     'InspectionID': 1697158,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FERN CREEK HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '9115 FERN CREEK RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-08-26 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FERN CREEK HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 78}},
#   {'attributes': {'EstablishmentID': 31511,
#     'InspectionID': 1737032,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FERN CREEK HIGH SCHOOL',
#     'PlaceName': None,
#     'Address': '9115 FERN CREEK RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-02-22 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FERN CREEK HIGH SCHOOL',
#     'Intersection': None,
#     'ObjectId': 79}},
#   {'attributes': {'EstablishmentID': 31512,
#     'InspectionID': 1716246,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EMMET FIELD SCHOOL',
#     'PlaceName': None,
#     'Address': '120 SACRED HEART LN',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40206,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-11-10 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EMMET FIELD SCHOOL',
#     'Intersection': None,
#     'ObjectId': 80}},
#   {'attributes': {'EstablishmentID': 31513,
#     'InspectionID': 1664315,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'FOSTER TRADITIONAL ACADEMY',
#     'PlaceName': None,
#     'Address': '1401 S 41ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-04-11 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FOSTER TRADITIONAL ACADEMY',
#     'Intersection': None,
#     'ObjectId': 81}},
#   {'attributes': {'EstablishmentID': 31513,
#     'InspectionID': 1708125,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FOSTER TRADITIONAL ACADEMY',
#     'PlaceName': None,
#     'Address': '1401 S 41ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2022-10-11 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FOSTER TRADITIONAL ACADEMY',
#     'Intersection': None,
#     'ObjectId': 82}},
#   {'attributes': {'EstablishmentID': 31513,
#     'InspectionID': 1739248,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'FOSTER TRADITIONAL ACADEMY',
#     'PlaceName': None,
#     'Address': '1401 S 41ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-03-02 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'FOSTER TRADITIONAL ACADEMY',
#     'Intersection': None,
#     'ObjectId': 83}},
#   {'attributes': {'EstablishmentID': 31513,
#     'InspectionID': 1737276,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'FOSTER TRADITIONAL ACADEMY',
#     'PlaceName': None,
#     'Address': '1401 S 41ST ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40211,
#     'TypeDescription': 'SCHOOL CAFETERIA OR FOOD SERVICE',
#     'InspectionDate': '2023-02-23 00:00:00',
#     'score': 93,
#     'Grade': 'C',
#     'NameSearch': 'FOSTER TRADITIONAL ACADEMY',
#     'Intersection': None,
#     'ObjectId': 84}},
#   {'attributes': {'EstablishmentID': 31575,
#     'InspectionID': 1670985,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'TREYTON OAK TOWERS',
#     'PlaceName': None,
#     'Address': '211 W OAK ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40203,
#     'TypeDescription': 'FOOD SERVICE (HOSPITAL / NURSING HOME',
#     'InspectionDate': '2022-05-09 00:00:00',
#     'score': 95,
#     'Grade': 'A',
#     'NameSearch': 'TREYTON OAK TOWERS',
#     'Intersection': None,
#     'ObjectId': 85}},
#   {'attributes': {'EstablishmentID': 31575,
#     'InspectionID': 1713369,
#     'Ins_TypeDesc': 'REGULAR',
# ...
#     'InspectionID': 1701056,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-05 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 969}},
#   {'attributes': {'EstablishmentID': 34326,
#     'InspectionID': 1672335,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SEVEN COUNTIES SERVICES',
#     'PlaceName': None,
#     'Address': '600 S PRESTON ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-05-09 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'SEVEN COUNTIES SERVICES',
#     'Intersection': None,
#     'ObjectId': 970}},
#   {'attributes': {'EstablishmentID': 34605,
#     'InspectionID': 1681893,
#     'Ins_TypeDesc': 'COMPLAINT',
#     'EstablishmentName': 'KROGER L-753',
#     'PlaceName': None,
#     'Address': '1265 GOSS AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-06-17 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'KROGER L-753',
#     'Intersection': None,
#     'ObjectId': 971}},
#   {'attributes': {'EstablishmentID': 36491,
#     'InspectionID': 1701057,
#     'Ins_TypeDesc': 'ENFORCEMENT ACTIONS',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-10 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 972}},
#   {'attributes': {'EstablishmentID': 34679,
#     'InspectionID': 1668072,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RUMORS',
#     'PlaceName': None,
#     'Address': '12339 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-04-26 00:00:00',
#     'score': 84,
#     'Grade': 'C',
#     'NameSearch': 'RUMORS',
#     'Intersection': None,
#     'ObjectId': 973}},
#   {'attributes': {'EstablishmentID': 34326,
#     'InspectionID': 1711049,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'SEVEN COUNTIES SERVICES',
#     'PlaceName': None,
#     'Address': '600 S PRESTON ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-10-20 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'SEVEN COUNTIES SERVICES',
#     'Intersection': None,
#     'ObjectId': 974}},
#   {'attributes': {'EstablishmentID': 34605,
#     'InspectionID': 1718696,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'KROGER L-753',
#     'PlaceName': None,
#     'Address': '1265 GOSS AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-11-22 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'KROGER L-753',
#     'Intersection': None,
#     'ObjectId': 975}},
#   {'attributes': {'EstablishmentID': 36491,
#     'InspectionID': 1701061,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-10 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 976}},
#   {'attributes': {'EstablishmentID': 34679,
#     'InspectionID': 1669631,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'RUMORS',
#     'PlaceName': None,
#     'Address': '12339 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-05-03 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'RUMORS',
#     'Intersection': None,
#     'ObjectId': 977}},
#   {'attributes': {'EstablishmentID': 34335,
#     'InspectionID': 1680029,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'GODFATHER II',
#     'PlaceName': None,
#     'Address': '5000 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-06-16 00:00:00',
#     'score': 99,
#     'Grade': 'A',
#     'NameSearch': 'GODFATHER II',
#     'Intersection': None,
#     'ObjectId': 978}},
#   {'attributes': {'EstablishmentID': 34605,
#     'InspectionID': 1717691,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'KROGER L-753',
#     'PlaceName': None,
#     'Address': '1265 GOSS AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-11-17 00:00:00',
#     'score': 96,
#     'Grade': 'C',
#     'NameSearch': 'KROGER L-753',
#     'Intersection': None,
#     'ObjectId': 979}},
#   {'attributes': {'EstablishmentID': 36491,
#     'InspectionID': 1703056,
#     'Ins_TypeDesc': 'COMPLAINT',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-05 00:00:00',
#     'score': 93,
#     'Grade': None,
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 980}},
#   {'attributes': {'EstablishmentID': 34679,
#     'InspectionID': 1716666,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'RUMORS',
#     'PlaceName': None,
#     'Address': '12339 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40243,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-11-14 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'RUMORS',
#     'Intersection': None,
#     'ObjectId': 981}},
#   {'attributes': {'EstablishmentID': 34335,
#     'InspectionID': 1737586,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'GODFATHER II',
#     'PlaceName': None,
#     'Address': '5000 PRESTON HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40213,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2023-02-23 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'GODFATHER II',
#     'Intersection': None,
#     'ObjectId': 982}},
#   {'attributes': {'EstablishmentID': 34605,
#     'InspectionID': 1717692,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'KROGER L-753',
#     'PlaceName': None,
#     'Address': '1265 GOSS AVE',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-11-17 00:00:00',
#     'score': 94,
#     'Grade': None,
#     'NameSearch': 'KROGER L-753',
#     'Intersection': None,
#     'ObjectId': 983}},
#   {'attributes': {'EstablishmentID': 36491,
#     'InspectionID': 1703057,
#     'Ins_TypeDesc': 'FOLLOWUP',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-05 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 984}},
#   {'attributes': {'EstablishmentID': 34681,
#     'InspectionID': 1699044,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'MIDLAND TRAIL GOLF COURSE',
#     'PlaceName': None,
#     'Address': '15360 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40223,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-09-02 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'MIDLAND TRAIL GOLF COURSE',
#     'Intersection': None,
#     'ObjectId': 985}},
#   {'attributes': {'EstablishmentID': 34358,
#     'InspectionID': 1679453,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EL NOPAL',
#     'PlaceName': None,
#     'Address': '6300 BARDSTOWN RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-06-13 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EL NOPAL',
#     'Intersection': None,
#     'ObjectId': 986}},
#   {'attributes': {'EstablishmentID': 34627,
#     'InspectionID': 1668702,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'WALMART #1170',
#     'PlaceName': None,
#     'Address': '10445 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40272,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-04-28 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'WALMART #1170',
#     'Intersection': None,
#     'ObjectId': 987}},
#   {'attributes': {'EstablishmentID': 36491,
#     'InspectionID': 1681906,
#     'Ins_TypeDesc': 'Education',
#     'EstablishmentName': 'WHITE CASTLE #15',
#     'PlaceName': None,
#     'Address': '700 W BROADWAY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40202,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-06-15 00:00:00',
#     'score': 0,
#     'Grade': None,
#     'NameSearch': 'WHITE CASTLE #15',
#     'Intersection': None,
#     'ObjectId': 988}},
#   {'attributes': {'EstablishmentID': 34681,
#     'InspectionID': 1735328,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'MIDLAND TRAIL GOLF COURSE',
#     'PlaceName': None,
#     'Address': '15360 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40223,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2023-02-15 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'MIDLAND TRAIL GOLF COURSE',
#     'Intersection': None,
#     'ObjectId': 989}},
#   {'attributes': {'EstablishmentID': 34358,
#     'InspectionID': 1718293,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'EL NOPAL',
#     'PlaceName': None,
#     'Address': '6300 BARDSTOWN RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40291,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-11-21 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'EL NOPAL',
#     'Intersection': None,
#     'ObjectId': 990}},
#   {'attributes': {'EstablishmentID': 34627,
#     'InspectionID': 1668703,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'WALMART #1170',
#     'PlaceName': None,
#     'Address': '10445 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40272,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-04-28 00:00:00',
#     'score': 97,
#     'Grade': None,
#     'NameSearch': 'WALMART #1170',
#     'Intersection': None,
#     'ObjectId': 991}},
#   {'attributes': {'EstablishmentID': 34627,
#     'InspectionID': 1712761,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'WALMART #1170',
#     'PlaceName': None,
#     'Address': '10445 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40272,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-10-27 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'WALMART #1170',
#     'Intersection': None,
#     'ObjectId': 992}},
#   {'attributes': {'EstablishmentID': 34627,
#     'InspectionID': 1712762,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'WALMART #1170',
#     'PlaceName': None,
#     'Address': '10445 DIXIE HWY',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40272,
#     'TypeDescription': 'RETAIL-FOOD  10,001 SQ FT OR OVER',
#     'InspectionDate': '2022-10-27 00:00:00',
#     'score': 98,
#     'Grade': None,
#     'NameSearch': 'WALMART #1170',
#     'Intersection': None,
#     'ObjectId': 993}},
#   {'attributes': {'EstablishmentID': 34628,
#     'InspectionID': 1706971,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'ORIENTAL HOUSE',
#     'PlaceName': None,
#     'Address': '4302 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-10-06 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'ORIENTAL HOUSE',
#     'Intersection': None,
#     'ObjectId': 994}},
#   {'attributes': {'EstablishmentID': 34628,
#     'InspectionID': 1745007,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'ORIENTAL HOUSE',
#     'PlaceName': None,
#     'Address': '4302 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2023-03-29 00:00:00',
#     'score': 98,
#     'Grade': 'A',
#     'NameSearch': 'ORIENTAL HOUSE',
#     'Intersection': None,
#     'ObjectId': 995}},
#   {'attributes': {'EstablishmentID': 34630,
#     'InspectionID': 1694009,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'AMERICAN LEGION',
#     'PlaceName': None,
#     'Address': '4610 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-12 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'AMERICAN LEGION',
#     'Intersection': None,
#     'ObjectId': 996}},
#   {'attributes': {'EstablishmentID': 34630,
#     'InspectionID': 1725535,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'AMERICAN LEGION',
#     'PlaceName': None,
#     'Address': '4610 SHELBYVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40207,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-12-22 00:00:00',
#     'score': 100,
#     'Grade': 'A',
#     'NameSearch': 'AMERICAN LEGION',
#     'Intersection': None,
#     'ObjectId': 997}},
#   {'attributes': {'EstablishmentID': 34643,
#     'InspectionID': 1671723,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'AMVETS POST 9',
#     'PlaceName': None,
#     'Address': '1567 S SHELBY ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-05-11 00:00:00',
#     'score': 94,
#     'Grade': 'A',
#     'NameSearch': 'AMVETS POST 9',
#     'Intersection': None,
#     'ObjectId': 998}},
#   {'attributes': {'EstablishmentID': 34643,
#     'InspectionID': 1720030,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'AMVETS POST 9',
#     'PlaceName': None,
#     'Address': '1567 S SHELBY ST',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40217,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-11-30 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'AMVETS POST 9',
#     'Intersection': None,
#     'ObjectId': 999}},
#   {'attributes': {'EstablishmentID': 34648,
#     'InspectionID': 1698250,
#     'Ins_TypeDesc': 'REGULAR',
#     'EstablishmentName': 'LE RELAIS',
#     'PlaceName': None,
#     'Address': '2817 TAYLORSVILLE RD',
#     'Address2': None,
#     'City': 'LOUISVILLE',
#     'State': 'KY',
#     'Zip': 40205,
#     'TypeDescription': 'FOOD SERVICE',
#     'InspectionDate': '2022-08-31 00:00:00',
#     'score': 97,
#     'Grade': 'A',
#     'NameSearch': 'LE RELAIS',
#     'Intersection': None,
#     'ObjectId': 1000}}]}

# %%
json.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'fields', 'exceededTransferLimit', 'features'])

# %%
df = pd.json_normalize(json, record_path =['features'])
df
# df.to_csv("rest_data.csv")
# Out:
#      attributes.EstablishmentID  attributes.InspectionID  \
# 0                         29956                  1684470
# 1                         29967                  1699737
# 2                         29979                  1698679
# 3                         29979                  1698680
# 4                         29979                  1731827
# ..                          ...                      ...
# 995                       34630                  1694009
# 996                       34630                  1725535
# 997                       34643                  1671723
# 998                       34643                  1720030
# 999                       34648                  1698250
#
#     attributes.Ins_TypeDesc attributes.EstablishmentName attributes.PlaceName  \
# 0                   REGULAR                    CVS #6211                 None
# 1                   REGULAR       NEIGHBORHOOD FOOD MART                 None
# 2                   REGULAR            CIRCLE K #4700075                 None
# 3                   REGULAR            CIRCLE K #4700075                 None
# 4                   REGULAR            CIRCLE K #4700075                 None
# ..                      ...                          ...                  ...
# 995                 REGULAR              AMERICAN LEGION                 None
# 996                 REGULAR              AMERICAN LEGION                 None
# 997                 REGULAR                AMVETS POST 9                 None
# 998                 REGULAR                AMVETS POST 9                 None
# 999                 REGULAR                    LE RELAIS                 None
#
#        attributes.Address attributes.Address2 attributes.City  \
# 0       3721 LEXINGTON RD                None      LOUISVILLE
# 1          542 LAMPTON ST                None      LOUISVILLE
# 2          1630 ARTHUR ST                None      LOUISVILLE
# 3          1630 ARTHUR ST                None      LOUISVILLE
# 4          1630 ARTHUR ST                None      LOUISVILLE
# ..                    ...                 ...             ...
# 995   4610 SHELBYVILLE RD                None      LOUISVILLE
# 996   4610 SHELBYVILLE RD                None      LOUISVILLE
# 997      1567 S SHELBY ST                None      LOUISVILLE
# 998      1567 S SHELBY ST                None      LOUISVILLE
# 999  2817 TAYLORSVILLE RD                None      LOUISVILLE
#
#     attributes.State  attributes.Zip         attributes.TypeDescription  \
# 0                 KY           40207                PRE-PACKAGED RETAIL
# 1                 KY           40203        SUPERMARKET WITH PROCESSING
# 2                 KY           40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# 3                 KY           40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# 4                 KY           40208  RETAIL-FOOD  10,000 SQ FT OR LESS
# ..               ...             ...                                ...
# 995               KY           40207                       FOOD SERVICE
# 996               KY           40207                       FOOD SERVICE
# 997               KY           40217                       FOOD SERVICE
# 998               KY           40217                       FOOD SERVICE
# 999               KY           40205                       FOOD SERVICE
#
#     attributes.InspectionDate  attributes.score attributes.Grade  \
# 0         2022-07-06 00:00:00               100             None
# 1         2022-09-07 00:00:00                97             None
# 2         2022-09-01 00:00:00                97                A
# 3         2022-09-01 00:00:00                98             None
# 4         2023-01-27 00:00:00                95                A
# ..                        ...               ...              ...
# 995       2022-08-12 00:00:00               100                A
# 996       2022-12-22 00:00:00               100                A
# 997       2022-05-11 00:00:00                94                A
# 998       2022-11-30 00:00:00                97                A
# 999       2022-08-31 00:00:00                97                A
#
#       attributes.NameSearch attributes.Intersection  attributes.ObjectId
# 0                 CVS #6211                    None                    1
# 1    NEIGHBORHOOD FOOD MART                    None                    2
# 2         CIRCLE K #4700075                    None                    3
# 3         CIRCLE K #4700075                    None                    4
# 4         CIRCLE K #4700075                    None                    5
# ..                      ...                     ...                  ...
# 995         AMERICAN LEGION                    None                  996
# 996         AMERICAN LEGION                    None                  997
# 997           AMVETS POST 9                    None                  998
# 998           AMVETS POST 9                    None                  999
# 999               LE RELAIS                    None                 1000
#
# [1000 rows x 17 columns]

# %%
# type(json['properties'])
# df = pd.DataFrame(json['features'])
# df.to_csv("rest_data.csv")

# %%
# df = pd.read_csv('rest_data.csv')
print(sorted(df))
# Out:
# ['attributes.Address', 'attributes.Address2', 'attributes.City', 'attributes.EstablishmentID', 'attributes.EstablishmentName', 'attributes.Grade', 'attributes.Ins_TypeDesc', 'attributes.InspectionDate', 'attributes.InspectionID', 'attributes.Intersection', 'attributes.NameSearch', 'attributes.ObjectId', 'attributes.PlaceName', 'attributes.State', 'attributes.TypeDescription', 'attributes.Zip', 'attributes.score']
